# %% [markdown]
# <a href="https://colab.research.google.com/github/mukulnag09/grammer-checker-using-bert/blob/main/grammar_checker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers==3.5.1
# !pip install torch==1.4.0
# !pip install wget
import csv

from transformers import BertForSequenceClassification

output_dir = '/content/drive/MyDrive/model_save'
from transformers import BertTokenizer
import torch
# Load the BERT tokenizer.
print('Loading BERT tokenizer...')
tokenizer = BertTokenizer.from_pretrained(output_dir,local_files_only=True)
model_loaded = BertForSequenceClassification.from_pretrained(output_dir)
# Out:
# ...
# Loading BERT tokenizer...

# %%
# Let's check it for a given sentence
import csv
with open('/content/drive/MyDrive/model_save/test_data.csv') as file_obj:
  reader_obj = csv.reader(file_obj)
  for row in reader_obj:
        print(row)
sent = "you have done good work"
encoded_dict = tokenizer.encode_plus(
                        sent,                      # Sentence to encode.
                        add_special_tokens = True, # Add '[CLS]' and '[SEP]'
                        max_length = 64,           # Pad & truncate all sentences.
                        pad_to_max_length = True,
                        return_attention_mask = True,   # Construct attn. masks.
                        return_tensors = 'pt',     # Return pytorch tensors.
                   )
    
    # Add the encoded sentence to the list.    
input_id = encoded_dict['input_ids']
    
    # And its attention mask (simply differentiates padding from non-padding).
attention_mask = encoded_dict['attention_mask']
input_id = torch.LongTensor(input_id)
attention_mask = torch.LongTensor(attention_mask)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model_loaded = model_loaded.to(device)
input_id = input_id.to(device)
attention_mask = attention_mask.to(device)
with torch.no_grad():
  # Forward pass, calculate logit predictions
  outputs = model_loaded(input_id, token_type_ids=None, attention_mask=attention_mask)

logits = outputs[0]
index = logits.argmax()
if index == 1:
  print("Gramatically correct")
  print(1)
else:
  print("Gramatically in-correct")
  print(0)
# Out:
# Streaming output truncated to the last 5000 lines.
# ['I am sure that I can get one of them in two days because I have already received a letter saying they will come back again to give it to me .']
# ['The way we are']
# ['Japanese rap musician']
# ['If ordinary female college students in Korea were , they would definitely prefer coffee from those popular brands .']
# ['In my opinion .']
# ['With eyes glued to the screen , watching their favorite cartoons , children can end up with poor eyesight .']
# ['Basil Good morning , sir !']
# ['All rooms are equipped with modern furniture .']
# ['I have been interested in this volunteer work for a long time , but I did not have much time to do it because I was busy .']
# ['Today I was watched it , interesting program broadcasted .']
# ['It is a serious problem ! !']
# ['When I went to a W .']
# ['I was not conscious untill my roommate woke me up .']
# ['I heard that Spanish was started from Latin , like English .']
# ...
